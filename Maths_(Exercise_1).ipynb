# %% [markdown]
# <a href="https://colab.research.google.com/github/AIPracticeUser/Mathematical-Foundations/blob/main/Maths_(Exercise_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image
Image("https://github.com/AIPracticeUser/Mathematical-Foundations/raw/31315c44498350560ecfc28032adb88adaeae44f/exercise1.jpg")

# %%
#Question 1
import numpy as np

# %%
x = np.array([[25],[2],[-3],[-23]])

# %%
result = x.T
result
# Out:
# array([[ 25,   2,  -3, -23]])

# %%
#Question 2
y = np.array([[42, 4, 7, 99], [-99, -3, 17, 22]])
y
# Out:
# array([[ 42,   4,   7,  99],
#        [-99,  -3,  17,  22]])

# %%
y.shape
# Out:
# (2, 4)

# %%
#Question 3
y[[1],[2]]
# Out:
# array([17])

# %% [markdown]
# So answer is $Y_{2,3}$, since python start with 0 as base
